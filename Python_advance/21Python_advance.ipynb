# %% [markdown]
# Q1. What is a probability distribution, exactly? If the values are meant to be random, how can you
# predict them at all?

# %% [raw]
# a probability distribution is a function that provides probabilities of the occurrence of different possible outcomes of the experiments. It can be shown via function, table, or graph. Probability is a long-term process of thinking that a certain outcome will come. All the random values are associated with some probabilities and if we have covered all cases and made a probability distribution function then we can predict that certain outcome.

# %% [markdown]
# Q2. Is there a distinction between true random numbers and pseudo-random numbers, if there is one? Why are the latter considered “good enough”?

# %% [raw]
# The true random number is randomly generated without considering any statistic significance. A pseudo-random number is generated by computer software that maintains some statistics. They are not secure as they are based on some algorithm and its deterministic while random number does not rely on that. Pseudo-random numbers are considered good enough because they are faster, rely on random sequence events, and are good for coding.

# %% [markdown]
# 3. What are the two main factors that influence the behaviour of a "normal" probability distribution?

# %% [raw]
# mean and standard deviation

# %% [markdown]
# Q4. Provide a real-life example of a normal distribution.

# %% [raw]
# Rolling of the dice

# %% [markdown]
# Q5. In the short term, how can you expect a probability distribution to behave? What do you think will happen as the number of trials grows?

# %% [raw]
# In short term, we can not make generalize probability distribution, as trails grow we can expect much better performance.

# %% [markdown]
# Q6. What kind of object can be shuffled by using random.shuffle?

# %% [raw]
# list object can be shuffled by random.shuffle

# %% [markdown]
# Q7. Describe the math package's general categories of functions.

# %% [raw]
# Numeric function
# constant
# Power function
# Log function
# Trigonometry function
# angular function

# %% [markdown]
# Q8. What is the relationship between exponentiation and logarithms?

# %% [raw]
# logarithm is an inverse operation of exponentiation.

# %% [markdown]
# Q9. What are the three logarithmic functions that Python supports?

# %% [raw]
# log, log2, log10.
