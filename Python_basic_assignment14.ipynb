# %% [markdown]
# 1.What does RGBA stand for?
# ans: its stand for red,green,blue and alpha where alpha shows how transparent image can be.

# %% [markdown]
# 2 From the Pillow module, how do you get the RGBA value of any images?

# %%
#ans
from PIL import Image
x=Image.open('sample.jpg')
x=x.convert("RGBA")
ans=x.getdata()
for i in ans:
    print(i)

# %% [markdown]
# 3.What is a box tuple, and how does it work?
# ans:Tuple box contain four values of the part of the image which is left,top,right,bottom. It helps in making changes in the image. Right and bottom value will be always actual value plus one.

# %% [markdown]
# 4.Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
#ans
from PIL import Image
x=Image.open('sample.jpg')
print("height:",x.height)
print("width:",x.width)
# Out:
# height: 210
# width: 280

# %% [markdown]
# 5.What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# ans: crop() method

# %%
#ans
from PIL import Image
x=Image.open('sample.jpg')
print(x.show())
y=x.crop((0,0,100,100))
print(y.show())
print(y.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=280x210>
# None
# <PIL.Image.Image image mode=RGB size=100x100>
# None
# (100, 100)

# %% [markdown]
# 6.After making changes to an Image object, how could you save it as an image file?
# ans: image.save()

# %%
#ans
from PIL import Image
x=Image.open('sample.jpg')
y=x.crop((0,0,100,100))
y=y.save('sample_changes.jpg')

# %% [markdown]
# 7.What module contains Pillow’s shape-drawing code?
# ans: ImageDraw module

# %% [markdown]
# 8.Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# ans: draw object does have drawing methods. It can be created by importing ImageDraw module and creatinf draw object.
